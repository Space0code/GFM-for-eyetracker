# %% [markdown]
# # Analysis of model outputs

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import os
import torch

# %%
results_dir = "../../../results"
cv_strats = ["subject_loo", "recording_loo", "combined_loo"]

# %% [markdown]
# ## First, baseline models

# %%
baseline_date = "2025-12-30_20-31-38"
baseline_dir = os.path.join(results_dir, "BaselineCV/eSEEd_v2", baseline_date)
baseline_models = ["MeanEstimator","LightGBM", "GaussianNB", "MLP", "SVM"]

# %%
# for each fold (left-out subject) in subject_loo, read y_pred.npy and y_true.npy
# aggregate all predictions and true values across folds, then plot histograms
for baseline_model in baseline_models:
    print("=========================================")
    print(f"\nBASELINE MODEL: {baseline_model}")

    for cv in cv_strats:
        print(f"\nCROSS-VALIDATION TYPE: {cv}")
        folds_dir = os.path.join(baseline_dir, cv, baseline_model)

        folds = sorted([f for f in os.listdir(folds_dir) if os.path.isdir(os.path.join(folds_dir, f))])
        
        # Initialize lists to collect all predictions and true values
        all_y_pred = []
        all_y_true = []
        
        for fold_idx, fold in enumerate(folds):
            fold_path = os.path.join(folds_dir, fold)
            pred_path = os.path.join(fold_path, "y_pred.npy")
            true_path = os.path.join(fold_path, "y_true.npy")
            
            if os.path.exists(pred_path) and os.path.exists(true_path):
                y_pred = np.load(pred_path)
                y_true = np.load(true_path)
                all_y_pred.append(y_pred)
                all_y_true.append(y_true)
            else:
                print(f"{pred_path} or {true_path} does not exist")
        
        # Concatenate all folds
        if all_y_pred and all_y_true:
            all_y_pred = np.concatenate(all_y_pred, axis=0)
            all_y_true = np.concatenate(all_y_true, axis=0)
            
            emotion_labels = ["anger", "disgust", "sadness", "tenderness"]
            emotion_colors_true = ["b", "g", "r", "c"]
            emotion_colors_pred = ["navy", "darkgreen", "darkred", "darkcyan"]
            
            # Plot all four emotions in a 2x2 grid
            fig, axes = plt.subplots(2, 2, figsize=(8, 4.5))
            for i, ax in enumerate(axes.ravel()):
                ax.hist(all_y_true[:, i], bins=30, alpha=0.5, label=f'True {emotion_labels[i]}',
                        density=True, color=emotion_colors_true[i], linestyle='-', edgecolor="grey")
                ax.hist(all_y_pred[:, i], bins=30, alpha=0.5, label=f'Pred {emotion_labels[i]}',
                        density=True, color=emotion_colors_pred[i], linestyle='--', edgecolor="black")
                ax.set_title(f'Emotion {emotion_labels[i]}')
                ax.set_xlabel('Intensity of emotion')
                ax.set_ylabel('Frequency')
                ax.legend()
            plt.suptitle(f'Baseline Model: {baseline_model} | CV Type: {cv}\nResults from all folds aggregated', y=1.02)
            plt.tight_layout()
            plt.show()
        else:
            print("No valid predictions found")
# Out:
# =========================================
#
# BASELINE MODEL: MeanEstimator
#
# CROSS-VALIDATION TYPE: subject_loo
# CROSS-VALIDATION TYPE: recording_loo
# CROSS-VALIDATION TYPE: combined_loo
# =========================================
#
# BASELINE MODEL: LightGBM
#
# CROSS-VALIDATION TYPE: subject_loo
# CROSS-VALIDATION TYPE: recording_loo
# CROSS-VALIDATION TYPE: combined_loo
# =========================================
#
# BASELINE MODEL: GaussianNB
#
# CROSS-VALIDATION TYPE: subject_loo
# CROSS-VALIDATION TYPE: recording_loo
# CROSS-VALIDATION TYPE: combined_loo
# =========================================
#
# BASELINE MODEL: MLP
#
# CROSS-VALIDATION TYPE: subject_loo
# CROSS-VALIDATION TYPE: recording_loo
# CROSS-VALIDATION TYPE: combined_loo
# =========================================
#
# BASELINE MODEL: SVM
#
# CROSS-VALIDATION TYPE: subject_loo
# CROSS-VALIDATION TYPE: recording_loo
# CROSS-VALIDATION TYPE: combined_loo

# %% [markdown]
# ## GNN

# %%
gnn_date = "2026-01-14_10-37-35"
gnn_dir = os.path.join(results_dir, "SpatioTemporalHeteroGNN/eSEEd_v2", gnn_date)
epoch_file_name = "epoch_010.pt"

# %%
for cv in cv_strats:
    print(f"\nCROSS-VALIDATION TYPE: {cv}")
    folds_dir = os.path.join(gnn_dir, cv)
    if os.path.exists(folds_dir) is False:
        print(f"{folds_dir} does not exist")
        continue
    folds = sorted([f for f in os.listdir(folds_dir) if os.path.isdir(os.path.join(folds_dir, f))])

    y_pred_list = []
    y_true_list = []

    for fold_idx, fold in enumerate(folds):
        data_dir = os.path.join(folds_dir, fold, "data")
        epoch = torch.load(os.path.join(data_dir, epoch_file_name))
        y_pred = epoch['outputs'].cpu().numpy()
        y_true = epoch['targets'].cpu().numpy()
        y_pred_list.append(y_pred)
        y_true_list.append(y_true)
    
    y_true_all = np.concatenate(y_true_list, axis=0)
    y_pred_all =  np.concatenate(y_pred_list, axis=0)

    emotion_labels = ["anger?", "tenderness", "sadness?", "disgust"]
    emotion_colors_true = ["b", "c", "r", "g"]
    emotion_colors_pred = ["navy", "darkcyan", "darkred", "darkgreen"]

    # Plot all four emotions in a 2x2 grid
    fig, axes = plt.subplots(2, 2, figsize=(10, 6.4))
    for i, ax in enumerate(axes.ravel()):
        ax.hist(y_true_all[:, i], bins=30, alpha=0.7, label=f'True {emotion_labels[i]}',
                density=True, color=emotion_colors_true[i], linestyle='-', edgecolor="grey")
        ax.hist(y_pred_all[:, i], bins=30, alpha=0.5, label=f'Pred {emotion_labels[i]}',
                density=True, color=emotion_colors_pred[i], linestyle='--', edgecolor="black")
        ax.set_title(f'Emotion {emotion_labels[i]}')
        ax.legend()
    plt.suptitle(f'SpatioTemporalHeteroGNN Model | CV Type: {cv}\nResults from all folds aggregated', y=1.02)
    plt.tight_layout()
    plt.show()
# Out:
# CROSS-VALIDATION TYPE: subject_loo
# CROSS-VALIDATION TYPE: recording_loo
# CROSS-VALIDATION TYPE: combined_loo
# ../../../results/SpatioTemporalHeteroGNN/eSEEd_v2/2026-01-14_10-37-35/combined_loo does not exist

# %%
print(epoch.keys())
epoch["metrics"]["per_emotion"].keys()
# Out:
# dict_keys(['outputs', 'targets', 'metrics'])
# dict_keys(['emotion-anger', 'emotion-disgust', 'emotion-sadness', 'emotion-tenderness'])

# %% [markdown]
# ## Difficult subjects based on MAE

# %%
for cv in cv_strats:
    print(f"\nCROSS-VALIDATION TYPE: {cv}")
    folds_dir = os.path.join(gnn_dir, cv)
    if os.path.exists(folds_dir) is False:
        print(f"{folds_dir} does not exist")
        continue
    folds = sorted([f for f in os.listdir(folds_dir) if os.path.isdir(os.path.join(folds_dir, f))])

    mae_dict = {}
    sd_dict = {}

    for fold_idx, fold in enumerate(folds):
        data_dir = os.path.join(folds_dir, fold, "data")
        epoch = torch.load(os.path.join(data_dir, epoch_file_name))

        metrics = epoch['metrics']
        metrics_agg = metrics['aggregated']
        metrics_per_emotion = metrics['per_emotion']

        for emotion in metrics_per_emotion.keys():
            mae = metrics_per_emotion[emotion]['mae']
            sd = metrics_per_emotion[emotion]['sd_error']
            if mae > 4:
                print(f"Fold {fold:<10} | Emotion: {emotion:<20} | MAE: {mae:>5.2f} | SD: {sd:>5.2f}")
            mae_dict.setdefault(emotion, []).append(mae)
            sd_dict.setdefault(emotion, []).append(sd)
        mae_dict.setdefault('aggregated', []).append(metrics_agg['mae'])
        sd_dict.setdefault('aggregated', []).append(metrics_agg['sd_error'])
# Out:
# CROSS-VALIDATION TYPE: subject_loo
# Fold subject_1  | Emotion: emotion-anger        | MAE:  4.15 | SD:  4.09
# Fold subject_1  | Emotion: emotion-disgust      | MAE:  4.66 | SD:  4.71
# Fold subject_1  | Emotion: emotion-sadness      | MAE:  4.58 | SD:  4.13
# Fold subject_10 | Emotion: emotion-anger        | MAE:  4.03 | SD:  4.24
# Fold subject_10 | Emotion: emotion-sadness      | MAE:  4.13 | SD:  4.16
# Fold subject_12 | Emotion: emotion-anger        | MAE:  4.07 | SD:  4.37
# Fold subject_12 | Emotion: emotion-disgust      | MAE:  4.34 | SD:  4.52
# Fold subject_15 | Emotion: emotion-sadness      | MAE:  5.88 | SD:  0.90
# Fold subject_16 | Emotion: emotion-anger        | MAE:  4.44 | SD:  4.53
# Fold subject_16 | Emotion: emotion-disgust      | MAE:  4.42 | SD:  4.31
# Fold subject_16 | Emotion: emotion-sadness      | MAE:  4.54 | SD:  4.36
# Fold subject_17 | Emotion: emotion-anger        | MAE:  4.27 | SD:  4.43
# Fold subject_17 | Emotion: emotion-disgust      | MAE:  4.32 | SD:  4.71
# Fold subject_17 | Emotion: emotion-sadness      | MAE:  4.20 | SD:  4.34
# Fold subject_19 | Emotion: emotion-anger        | MAE:  4.11 | SD:  3.75
# Fold subject_19 | Emotion: emotion-disgust      | MAE:  4.55 | SD:  4.14
# Fold subject_19 | Emotion: emotion-sadness      | MAE:  4.61 | SD:  4.14
# Fold subject_20 | Emotion: emotion-disgust      | MAE:  4.27 | SD:  4.18
# Fold subject_20 | Emotion: emotion-sadness      | MAE:  4.02 | SD:  3.97
# Fold subject_22 | Emotion: emotion-disgust      | MAE:  4.07 | SD:  4.18
# Fold subject_23 | Emotion: emotion-disgust      | MAE:  4.39 | SD:  4.50
# Fold subject_23 | Emotion: emotion-sadness      | MAE:  4.02 | SD:  4.23
# Fold subject_28 | Emotion: emotion-anger        | MAE:  4.35 | SD:  4.56
# Fold subject_28 | Emotion: emotion-disgust      | MAE:  4.55 | SD:  4.27
# Fold subject_28 | Emotion: emotion-sadness      | MAE:  4.38 | SD:  4.14
# Fold subject_30 | Emotion: emotion-disgust      | MAE:  4.59 | SD:  4.94
# Fold subject_32 | Emotion: emotion-sadness      | MAE:  4.12 | SD:  4.16
# Fold subject_33 | Emotion: emotion-disgust      | MAE:  4.08 | SD:  3.68
# Fold subject_34 | Emotion: emotion-sadness      | MAE:  4.24 | SD:  4.31
# Fold subject_35 | Emotion: emotion-anger        | MAE:  4.87 | SD:  3.98
# Fold subject_35 | Emotion: emotion-disgust      | MAE:  5.09 | SD:  4.56
# Fold subject_35 | Emotion: emotion-sadness      | MAE:  4.52 | SD:  3.95
# Fold subject_4  | Emotion: emotion-anger        | MAE:  4.02 | SD:  4.32
# Fold subject_4  | Emotion: emotion-disgust      | MAE:  4.33 | SD:  4.13
# Fold subject_4  | Emotion: emotion-sadness      | MAE:  4.01 | SD:  4.30
# Fold subject_40 | Emotion: emotion-anger        | MAE:  4.51 | SD:  4.47
# Fold subject_40 | Emotion: emotion-disgust      | MAE:  4.83 | SD:  4.87
# Fold subject_40 | Emotion: emotion-sadness      | MAE:  4.08 | SD:  4.22
# Fold subject_42 | Emotion: emotion-sadness      | MAE:  4.07 | SD:  3.78
# Fold subject_44 | Emotion: emotion-sadness      | MAE:  4.38 | SD:  1.75
# Fold subject_46 | Emotion: emotion-anger        | MAE:  4.39 | SD:  4.24
# Fold subject_46 | Emotion: emotion-disgust      | MAE:  4.24 | SD:  4.37
# Fold subject_46 | Emotion: emotion-sadness      | MAE:  4.16 | SD:  4.09
# Fold subject_47 | Emotion: emotion-disgust      | MAE:  4.57 | SD:  4.57
# Fold subject_47 | Emotion: emotion-sadness      | MAE:  4.41 | SD:  4.18
# Fold subject_5  | Emotion: emotion-disgust      | MAE:  4.21 | SD:  4.35
# Fold subject_6  | Emotion: emotion-sadness      | MAE:  4.17 | SD:  4.21
#
# CROSS-VALIDATION TYPE: recording_loo
# Fold recording_1 | Emotion: emotion-disgust      | MAE:  4.05 | SD:  1.28
# Fold recording_4 | Emotion: emotion-anger        | MAE:  4.02 | SD:  1.55
# Fold recording_4 | Emotion: emotion-disgust      | MAE:  4.55 | SD:  1.01
# Fold recording_7 | Emotion: emotion-anger        | MAE:  4.39 | SD:  3.35
# Fold recording_7 | Emotion: emotion-disgust      | MAE:  4.71 | SD:  3.57
# Fold recording_8 | Emotion: emotion-anger        | MAE:  4.45 | SD:  4.52
# Fold recording_8 | Emotion: emotion-disgust      | MAE:  5.67 | SD:  2.96
#
# CROSS-VALIDATION TYPE: combined_loo
# ../../../results/SpatioTemporalHeteroGNN/eSEEd_v2/2026-01-14_10-37-35/combined_loo does not exist
